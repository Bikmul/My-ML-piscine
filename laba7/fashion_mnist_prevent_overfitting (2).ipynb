# %%
from keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation,Conv2D,MaxPooling2D
from tensorflow.keras import utils
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from keras.optimizers import SGD
from google.colab import files
import matplotlib.pyplot as plt
from PIL import Image
import numpy
# %matplotlib inline

# %%
# Задаем seed для повторяемости результатов
numpy.random.seed(42)

# Загружаем данные
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Размер мини-выборки
batch_size = 32
# Количество классов изображений
nb_classes = 10
# Количество эпох для обучения
nb_epoch = 25
# Размер изображений
img_rows, img_cols = 32, 32
# Количество каналов в изображении: RGB
img_channels = 3

# Нормализуем данные
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Преобразуем метки в категории
Y_train = to_categorical(y_train, nb_classes)
Y_test = to_categorical(y_test, nb_classes)

# Создаем последовательную модель
model = Sequential()
# Первый сверточный слой
model.add(Conv2D(32, (3, 3), padding='same',
                        input_shape=(32, 32, 3), activation='relu'))
# Второй сверточный слой
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
# Первый слой подвыборки
model.add(MaxPooling2D(pool_size=(2, 2)))
# Слой регуляризации Dropout
model.add(Dropout(0.25))

# Третий сверточный слой
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
# Четвертый сверточный слой
model.add(Conv2D(64, (3, 3), activation='relu'))
# Второй слой подвыборки
model.add(MaxPooling2D(pool_size=(2, 2)))
# Слой регуляризации Dropout
model.add(Dropout(0.25))
# Слой преобразования данных из 2D представления в плоское
model.add(Flatten())
# Полносвязный слой для классификации
model.add(Dense(512, activation='relu'))
# Слой регуляризации Dropout
model.add(Dropout(0.5))
# Выходной полносвязный слой
model.add(Dense(nb_classes, activation='softmax'))

# %%
# Задаем параметры оптимизации
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
# Обучаем модель
model.fit(X_train, Y_train,
              batch_size=batch_size,
              epochs=nb_epoch,
              validation_split=0.1,
              shuffle=True,
              verbose=2)

# Оцениваем качество обучения модели на тестовых данных
scores = model.evaluate(X_test, Y_test, verbose=0)
print("Точность работы на тестовых данных: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/25
# 1407/1407 - 17s - loss: 1.7186 - accuracy: 0.3678 - val_loss: 1.3341 - val_accuracy: 0.5062 - 17s/epoch - 12ms/step
# Epoch 2/25
# 1407/1407 - 7s - loss: 1.2836 - accuracy: 0.5383 - val_loss: 1.0639 - val_accuracy: 0.6334 - 7s/epoch - 5ms/step
# Epoch 3/25
# 1407/1407 - 7s - loss: 1.1218 - accuracy: 0.5990 - val_loss: 0.9541 - val_accuracy: 0.6730 - 7s/epoch - 5ms/step
# Epoch 4/25
# 1407/1407 - 7s - loss: 0.9963 - accuracy: 0.6452 - val_loss: 0.8536 - val_accuracy: 0.7016 - 7s/epoch - 5ms/step
# Epoch 5/25
# 1407/1407 - 7s - loss: 0.9118 - accuracy: 0.6788 - val_loss: 0.7755 - val_accuracy: 0.7236 - 7s/epoch - 5ms/step
# Epoch 6/25
# 1407/1407 - 7s - loss: 0.8550 - accuracy: 0.6980 - val_loss: 0.7911 - val_accuracy: 0.7250 - 7s/epoch - 5ms/step
# Epoch 7/25
# 1407/1407 - 7s - loss: 0.8117 - accuracy: 0.7146 - val_loss: 0.7087 - val_accuracy: 0.7552 - 7s/epoch - 5ms/step
# Epoch 8/25
# 1407/1407 - 7s - loss: 0.7783 - accuracy: 0.7264 - val_loss: 0.6755 - val_accuracy: 0.7640 - 7s/epoch - 5ms/step
# Epoch 9/25
# 1407/1407 - 7s - loss: 0.7350 - accuracy: 0.7428 - val_loss: 0.6915 - val_accuracy: 0.7658 - 7s/epoch - 5ms/step
# Epoch 10/25
# 1407/1407 - 7s - loss: 0.7123 - accuracy: 0.7511 - val_loss: 0.6741 - val_accuracy: 0.7698 - 7s/epoch - 5ms/step
# Epoch 11/25
# 1407/1407 - 7s - loss: 0.6925 - accuracy: 0.7586 - val_loss: 0.6901 - val_accuracy: 0.7640 - 7s/epoch - 5ms/step
# Epoch 12/25
# 1407/1407 - 7s - loss: 0.6697 - accuracy: 0.7653 - val_loss: 0.6853 - val_accuracy: 0.7702 - 7s/epoch - 5ms/step
# Epoch 13/25
# 1407/1407 - 7s - loss: 0.6558 - accuracy: 0.7735 - val_loss: 0.7003 - val_accuracy: 0.7628 - 7s/epoch - 5ms/step
# Epoch 14/25
# 1407/1407 - 7s - loss: 0.6456 - accuracy: 0.7717 - val_loss: 0.6564 - val_accuracy: 0.7780 - 7s/epoch - 5ms/step
# Epoch 15/25
# 1407/1407 - 7s - loss: 0.6266 - accuracy: 0.7814 - val_loss: 0.6852 - val_accuracy: 0.7758 - 7s/epoch - 5ms/step
# Epoch 16/25
# 1407/1407 - 7s - loss: 0.6272 - accuracy: 0.7806 - val_loss: 0.7056 - val_accuracy: 0.7636 - 7s/epoch - 5ms/step
# Epoch 17/25
# 1407/1407 - 7s - loss: 0.6185 - accuracy: 0.7857 - val_loss: 0.6663 - val_accuracy: 0.7784 - 7s/epoch - 5ms/step
# Epoch 18/25
# 1407/1407 - 8s - loss: 0.6076 - accuracy: 0.7893 - val_loss: 0.6866 - val_accuracy: 0.7712 - 8s/epoch - 6ms/step
# Epoch 19/25
# 1407/1407 - 9s - loss: 0.6036 - accuracy: 0.7914 - val_loss: 0.6658 - val_accuracy: 0.7782 - 9s/epoch - 7ms/step
# Epoch 20/25
# 1407/1407 - 8s - loss: 0.5983 - accuracy: 0.7926 - val_loss: 0.6896 - val_accuracy: 0.7766 - 8s/epoch - 6ms/step
# Epoch 21/25
# 1407/1407 - 8s - loss: 0.5858 - accuracy: 0.7987 - val_loss: 0.6831 - val_accuracy: 0.7764 - 8s/epoch - 5ms/step
# Epoch 22/25
# 1407/1407 - 7s - loss: 0.5730 - accuracy: 0.8047 - val_loss: 0.6517 - val_accuracy: 0.7834 - 7s/epoch - 5ms/step
# Epoch 23/25
# 1407/1407 - 6s - loss: 0.5704 - accuracy: 0.8027 - val_loss: 0.7143 - val_accuracy: 0.7686 - 6s/epoch - 5ms/step
# Epoch 24/25
# 1407/1407 - 7s - loss: 0.5799 - accuracy: 0.8006 - val_loss: 0.6428 - val_accuracy: 0.7920 - 7s/epoch - 5ms/step
# Epoch 25/25
# 1407/1407 - 6s - loss: 0.5691 - accuracy: 0.8030 - val_loss: 0.7014 - val_accuracy: 0.7726 - 6s/epoch - 5ms/step
# Точность работы на тестовых данных: 76.03%
